# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset= pd.read_excel("Book3.xlsx")
dataset.head(5)
# Out:
#    cgpa  score  place
# 0   4.5  3.260      1
# 1   5.6  1.980      1
# 2   6.7  3.250      0
# 3   7.8  2.820      1
# 4   8.9  2.815      2

# %%
x= dataset.iloc[:,:-1]
y= dataset["place"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr= LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 73.52941176470588

# %%
from sklearn.metrics import confusion_matrix, precision_score,recall_score,f1_score

# %%
cf=confusion_matrix(y_test,lr.predict(x_test))
cf
# Out:
# array([[ 0,  8,  0],
#        [ 0, 25,  0],
#        [ 0,  1,  0]], dtype=int64)

# %%
sns.heatmap(cf,annot=True)
plt.show()

# %%
precision_score(y_test,lr.predict(x_test))*100
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 precision_score(y_test,lr.predict(x_test))*100
#
# File c:\Users\MUHIB\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File c:\Users\MUHIB\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:2182, in precision_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    2015 @validate_params(
#    2016     {
#    2017         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    2042     zero_division="warn",
#    2043 ):
#    2044     """Compute the precision.
#    2045
#    2046     The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    2180     array([0.5, 1. , 1. ])
#    2181     """
# -> 2182     p, _, _, _ = precision_recall_fscore_support(
#    2183         y_true,
#    2184         y_pred,
#    2185         labels=labels,
#    2186         pos_label=pos_label,
#    2187         average=average,
#    2188         warn_for=("precision",),
#    2189         sample_weight=sample_weight,
#    2190         zero_division=zero_division,
#    2191     )
#    2192     return p
#
# File c:\Users\MUHIB\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File c:\Users\MUHIB\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1767, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1604 """Compute precision, recall, F-measure and support for each class.
#    1605
#    1606 The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    1764  array([2, 2, 2]))
#    1765 """
#    1766 _check_zero_division(zero_division)
# -> 1767 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1769 # Calculate tp_sum, pred_sum, true_sum ###
#    1770 samplewise = average == "samples"
#
# File c:\Users\MUHIB\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1556, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1554         if y_type == "multiclass":
#    1555             average_options.remove("samples")
# -> 1556         raise ValueError(
#    1557             "Target is %s but average='binary'. Please "
#    1558             "choose another average setting, one of %r." % (y_type, average_options)
#    1559         )
#    1560 elif pos_label not in (None, 1):
#    1561     warnings.warn(
#    1562         "Note that pos_label (set to %r) is ignored when "
#    1563         "average != 'binary' (got %r). You may use "
#    (...)
#    1566         UserWarning,
#    1567     )
#
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].

# %%
recall_score(y_test,lr.predict(x_test))*100
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 recall_score(y_test,lr.predict(x_test))*100
#
# File c:\Users\MUHIB\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File c:\Users\MUHIB\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:2363, in recall_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    2195 @validate_params(
#    2196     {
#    2197         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    2222     zero_division="warn",
#    2223 ):
#    2224     """Compute the recall.
#    2225
#    2226     The recall is the ratio ``tp / (tp + fn)`` where ``tp`` is the number of
#    (...)
#    2361     array([1. , 1. , 0.5])
#    2362     """
# -> 2363     _, r, _, _ = precision_recall_fscore_support(
#    2364         y_true,
#    2365         y_pred,
#    2366         labels=labels,
#    2367         pos_label=pos_label,
#    2368         average=average,
#    2369         warn_for=("recall",),
#    2370         sample_weight=sample_weight,
#    2371         zero_division=zero_division,
#    2372     )
#    2373     return r
#
# File c:\Users\MUHIB\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File c:\Users\MUHIB\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1767, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1604 """Compute precision, recall, F-measure and support for each class.
#    1605
#    1606 The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    1764  array([2, 2, 2]))
#    1765 """
#    1766 _check_zero_division(zero_division)
# -> 1767 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1769 # Calculate tp_sum, pred_sum, true_sum ###
#    1770 samplewise = average == "samples"
#
# File c:\Users\MUHIB\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1556, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1554         if y_type == "multiclass":
#    1555             average_options.remove("samples")
# -> 1556         raise ValueError(
#    1557             "Target is %s but average='binary'. Please "
#    1558             "choose another average setting, one of %r." % (y_type, average_options)
#    1559         )
#    1560 elif pos_label not in (None, 1):
#    1561     warnings.warn(
#    1562         "Note that pos_label (set to %r) is ignored when "
#    1563         "average != 'binary' (got %r). You may use "
#    (...)
#    1566         UserWarning,
#    1567     )
#
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].

# %%
f1_score(y_test,lr.predict(x_test))*100
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 f1_score(y_test,lr.predict(x_test))*100
#
# File c:\Users\MUHIB\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File c:\Users\MUHIB\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1271, in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1091 @validate_params(
#    1092     {
#    1093         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    1118     zero_division="warn",
#    1119 ):
#    1120     """Compute the F1 score, also known as balanced F-score or F-measure.
#    1121
#    1122     The F1 score can be interpreted as a harmonic mean of the precision and
#    (...)
#    1269     array([0.66666667, 1.        , 0.66666667])
#    1270     """
# -> 1271     return fbeta_score(
#    1272         y_true,
#    1273         y_pred,
#    1274         beta=1,
#    1275         labels=labels,
#    1276         pos_label=pos_label,
#    1277         average=average,
#    1278         sample_weight=sample_weight,
#    1279         zero_division=zero_division,
#    1280     )
#
# File c:\Users\MUHIB\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File c:\Users\MUHIB\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1463, in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1283 @validate_params(
#    1284     {
#    1285         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    1312     zero_division="warn",
#    1313 ):
#    1314     """Compute the F-beta score.
#    1315
#    1316     The F-beta score is the weighted harmonic mean of precision and recall,
#    (...)
#    1460     0.12...
#    1461     """
# -> 1463     _, _, f, _ = precision_recall_fscore_support(
#    1464         y_true,
#    1465         y_pred,
#    1466         beta=beta,
#    1467         labels=labels,
#    1468         pos_label=pos_label,
#    1469         average=average,
#    1470         warn_for=("f-score",),
#    1471         sample_weight=sample_weight,
#    1472         zero_division=zero_division,
#    1473     )
#    1474     return f
#
# File c:\Users\MUHIB\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File c:\Users\MUHIB\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1767, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1604 """Compute precision, recall, F-measure and support for each class.
#    1605
#    1606 The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    1764  array([2, 2, 2]))
#    1765 """
#    1766 _check_zero_division(zero_division)
# -> 1767 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1769 # Calculate tp_sum, pred_sum, true_sum ###
#    1770 samplewise = average == "samples"
#
# File c:\Users\MUHIB\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1556, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1554         if y_type == "multiclass":
#    1555             average_options.remove("samples")
# -> 1556         raise ValueError(
#    1557             "Target is %s but average='binary'. Please "
#    1558             "choose another average setting, one of %r." % (y_type, average_options)
#    1559         )
#    1560 elif pos_label not in (None, 1):
#    1561     warnings.warn(
#    1562         "Note that pos_label (set to %r) is ignored when "
#    1563         "average != 'binary' (got %r). You may use "
#    (...)
#    1566         UserWarning,
#    1567     )
#
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
