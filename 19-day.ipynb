# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset= pd.read_excel("Book4.xlsx")
dataset.head(6)
# Out:
#    age  exp     sa
# 0   50   10  99432
# 1   36    6  54432
# 2   34    5  43432
# 3   42    7  44432
# 4   44    9  87432
# 5   40    5  76432

# %%
dataset.shape
# Out:
# (18, 3)

# %%
dataset.isnull().sum()
# Out:
# age    0
# exp    0
# sa     0
# dtype: int64

# %%
sns.pairplot(data=dataset)
plt.show()

# %%
sns.heatmap(data=dataset.corr(),annot=True)
plt.show()

# %%
x=dataset.iloc[:,:-1]
y=dataset["sa"]

# %%
dataset.shape
# Out:
# (18, 3)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# -501.0205984316923

# %%
lr.coef_
# Out:
# array([ -57.57959884, 7479.24509428])

# %%
lr.intercept_
# Out:
# 1206.710217745851

# %%
lr.predict(x_test)
# Out:
# array([73120.18121835, 44009.31522504, 22032.21673295, 36299.75173539])
