# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions
from sklearn.datasets import make_moons

# %%
x,y=make_moons(n_samples=250,noise=0.05)

# %%
df={"cgpa":x[:,0], "score":x[:,1],"place":y}

# %%
dataset=pd.DataFrame(df)

# %%
dataset.head(3)
# Out:
#        cgpa     score  place
# 0 -1.017281  0.214425      0
# 1  0.807943  0.627616      0
# 2  0.759584 -0.462829      1

# %%
sns.scatterplot(x="cgpa",y="score",data=dataset,hue="place")
plt.show()

# %%
x=dataset.iloc[:,:-1]
y=dataset["place"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import Perceptron

# %%
pr=Perceptron()
pr.fit(x_train,y_train)
# Out:
# Perceptron()

# %%
pr.score(x_train,y_train)*100, pr.score(x_test,y_test)*100
# Out:
# (85.5, 86.0)

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=pr)
plt.show()
# Out:
# c:\Users\MUHIB\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
